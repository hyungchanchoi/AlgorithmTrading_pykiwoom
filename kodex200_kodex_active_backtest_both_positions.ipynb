# %% [markdown]
# <a href="https://colab.research.google.com/github/hyungchanchoi/AlgorithmTrading_pykiwoom/blob/main/kodex200_kodex_active_backtest_both_positions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from datetime import datetime,timedelta   ;today = datetime.today().strftime("%Y%m%d") 
from sklearn.preprocessing import minmax_scale
from statsmodels.tsa.stattools import coint
pd.options.display.float_format = '{:.6f}'.format
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Mounted at /content/drive

# %%
cd drive/My Drive/algorithmtrading/pair_trading
# Out:
# /content/drive/My Drive/algorithmtrading/pair_trading

# %%
def one_day(temp,test_day):
    
    begin = np.where( np.array(temp.index) > str(test_day))[0][0]
    end = np.where( str(test_day+1) > np.array(temp.index) )[0][-1]
    
    if len(temp.iloc[begin:end])==0:
        print(test_day,'는 공휴일 입니다.')
    else:
        return temp.iloc[begin-1:end]

def get_period(temp,start,finish):
    
    begin = np.where( np.array(temp.index) > str(start))[0][0]
    end = np.where( str(finish+1) > np.array(temp.index) )[0][-1]
    
    return temp.iloc[begin-1:end]

def get_data(temps,start,finish):
    temps = get_period(temp,start,finish)
    temps['kodex200_dayret'] = np.log(temps['kodex200']/temps['kodex200'][0])
    temps['kodex_active_dayret'] = np.log(temps['kodex_active']/temps['kodex_active'][0])
    temps['dayret_spread_kodex'] = temps['kodex_active_dayret'] - temps['kodex200_dayret']
    temps['cumret_spread_kodex'] = temps['kodex_active_cumret'] - temps['kodex200_cumret']
    temps['tiger_active_dayret'] = np.log(temps['tiger_active']/temps['tiger_active'][0])       
    temps['dayret_spread_tiger'] = temps['tiger_active_dayret'] - temps['kodex200_dayret']
    temps['cumret_spread_tiger'] = temps['tiger_active_cumret'] - temps['kodex200_cumret'] 
    return temps

# %% [markdown]
# ## - 과거 1분단위 데이터 받아오기

# %%
now = '_1229'

kodex200 = pd.read_pickle('kodex200'+now)
kodex_inv = pd.read_pickle('kodex_inv'+now)
# kodex_x2 = pd.read_pickle('kodex_x2'+now)
# kodex_inv = pd.read_pickle('kodex_inversex2'+now)
kodex_active = pd.read_pickle('kodex_active'+now)
tiger_active = pd.read_pickle('tiger_active'+now)
temp =  pd.merge(left = kodex200 , right = kodex_inv, how = "inner", on = "time")
temp =  pd.merge(left = temp , right = kodex_active, how = "inner", on = "time")
temp =  pd.merge(left = temp , right = tiger_active, how = "inner", on = "time")
temp.columns = ['kodex200','kodex_inv','kodex_active','tiger_active']
temp['kodex200_cumret'] = np.log(temp['kodex200']/temp['kodex200'][0])
temp['kodex_inv_cumret'] = np.log(temp['kodex_inv']/temp['kodex_inv'][0])
temp['kodex_active_cumret'] = np.log(temp['kodex_active']/temp['kodex_active'][0])
temp['cumret_spread_kodex'] = temp['kodex_active_cumret'] - temp['kodex200_cumret']
temp['ma5'] = temp['cumret_spread_kodex'].rolling(window=5, center=False).mean()
temp['ma10'] = temp['cumret_spread_kodex'].rolling(window=10, center=False).mean()
temp['ma20'] = temp['cumret_spread_kodex'].rolling(window=20, center=False).mean()
temp['ma30'] = temp['cumret_spread_kodex'].rolling(window=30, center=False).mean()
temp['tiger_active_cumret'] = np.log(temp['tiger_active']/temp['tiger_active'][0])
temp['cumret_spread_tiger'] = temp['tiger_active_cumret'] - temp['kodex200_cumret']
temp['ma5'] = temp['cumret_spread_tiger'].rolling(window=5, center=False).mean()
temp['ma10'] = temp['cumret_spread_tiger'].rolling(window=10, center=False).mean()
temp['ma20'] = temp['cumret_spread_tiger'].rolling(window=20, center=False).mean()
temp['ma30'] = temp['cumret_spread_tiger'].rolling(window=30, center=False).mean()
temp
# Out:
#                kodex200  kodex_inv  ...  tiger_active_cumret  cumret_spread_tiger
# time                                ...
# 20200929.901      31030       5485  ...             0.000000             0.000000
# 20200929.902      31010       5485  ...             0.000000             0.000645
# 20200929.903      31035       5480  ...             0.000000            -0.000161
# 20200929.904      31015       5480  ...             0.000000             0.000484
# 20200929.905      31010       5480  ...             0.000000             0.000645
# ...                 ...        ...  ...                  ...                  ...
# 20201229.1506     38545       4375  ...             0.191357            -0.025515
# 20201229.1509     38560       4370  ...             0.191357            -0.025904
# 20201229.1510     38545       4375  ...             0.190948            -0.025924
# 20201229.1517     38550       4375  ...             0.191357            -0.025645
# 20201229.1530     38685       4365  ...             0.192174            -0.028324
#
# [1982 rows x 14 columns]

# %% [markdown]
# ## - 일 단위로 데이터 저장하기 + 당일 수익률 계산

# %%
df = {}
calender = []
for date in range(20200929,20201229):
    temps = pd.DataFrame()
    temps = one_day(temp,date)
    try:
        temps['kodex200_dayret'] = np.log(temps['kodex200']/temps['kodex200'][0])
        temps['kodex_inv_dayret'] = np.log(temps['kodex_inv']/temps['kodex_inv'][0])
        temps['kodex_active_dayret'] = np.log(temps['kodex_active']/temps['kodex_active'][0])
        temps['dayret_spread_kodex'] = temps['kodex_active_dayret'] - temps['kodex200_dayret']
        temps['tiger_active_dayret'] = np.log(temps['tiger_active']/temps['tiger_active'][0])
        temps['dayret_spread_tiger'] = temps['tiger_active_dayret'] - temps['kodex200_dayret']       
        df[str(date)] = temps
        calender.append(date)
    except:
        pass

# %% [markdown]
# # - 알고리즘

# %% [markdown]
# ### 알고리즘 0번

# %%
#Trade using a simple strategy
def algo_0( start, finish , money):

    # date = [x for x in calender if finish >= x >= start ]
    
    df = get_data(temp,start, finish)
    
    fee_buy = (1.00015)
    fee_sell = (1-0.00015)
    
    # Simulate trading
    S1 = df['kodex_active']
    S2 = df['kodex_x2']
    S3 = df['kodex_invx2']

    # Start with no money and no positions        
    count_S1 = 0
    count_S2 = 0    
    count_S3 = 0  

    spread = df['dayret_spread_kodex']  
    
    cash = money
    
    #start trading
    for i in range(1,len(df)):        
        
        money = cash
        print(i,'번째거래')
        
        if cash < min(S1[i],S2[i],S3[i]) :
            print('금액부족')
            continue  
        
        # buy short if the z-score is > 1
        if  spread[i] > threshold:   # sell S1  buy S2

            count_S1 -= lev
            count_S2 += lev

            cash +=  S1[i] * lev * fee_sell - S2[i] * lev * fee_buy

            eval_S1 = count_S1 * S1[i] *fee_buy
            eval_S2 = count_S2 * S2[i] *fee_sell
            eval_total = eval_S1+ eval_S2 

            print( '-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S2[i], '  /  spread :',spread[i])
            print('[sell_INFO]    kodex_active  매도금액 : ',S1[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',S2[i]*lev* fee_buy,
                    'kodex_active : ',count_S1,'주  /  kodex_x2 : ',count_S2,'주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

            

        elif  spread[i] < - threshold :   # buy S1  sell S2

            count_S1 += lev
            count_S3 += lev

            cash -=  S1[i] * lev * fee_buy + S3[i] * lev * fee_buy

            eval_S1 = count_S1 * S1[i] *fee_sell
            eval_S3 = count_S3 * S3[i] *fee_sell
            eval_total = eval_S1+ eval_S3 

            print( '-----------',' kodex_active 현재가 :',S1[i],' / kodex_x2 현재가 :',S3[i], '  /  spread :',spread[i])
            print('[buy_INFO]   kodex_active 매수금액 :',S1[i]* lev*fee_buy,'/  kodex_x2 매수금액 :',S3[i]*lev* fee_buy,
                    'kodex_active : ',count_S1,'주  /  kodex_x2 : ',count_S3,'주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
    

        # Clear positions if the z-score between -.5 and .5        
        # -0.5~0.5 사이인 경우 수익일 경우 이익 실현
        elif abs(spread[i]) < threshold :           

            if count_S1 > 0 :
                eval_S1 = count_S1 * S1[i] * fee_sell
                eval_S3 = count_S3 * S3[i] * fee_sell
                eval_total = eval_S1 + eval_S3
                    
                temp_cash = cash + eval_S1 + eval_S3 
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0 
                    count_S3 = 0 
                    print('-----------','kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S3[i])
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S1,'원',' / 총매도금액 :', eval_S3  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:',count_S3,'주' ) 
            
            if count_S1 < 0 :
                eval_S1 = count_S1 * S1[i] * fee_buy
                eval_S2 = count_S2 * S2[i] * fee_sell
                eval_total = eval_S1 + eval_S2
                    
                temp_cash = cash + eval_S1 + eval_S2 
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0 
                    count_S2 = 0 
                    print('-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S2[i])
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S1,'원',' / 총매도금액 :', eval_S2  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:',count_S2,'주' ) 

        else:
            pass  

            
    if count_S1 > 0 :
        eval_S1 = count_S1 * S1[-1] * fee_sell
        eval_S2 = count_S2 * S2[-1] * fee_sell
        eval_S3 = count_S3 * S3[-1] * fee_sell
        cash += eval_S1 + eval_S2 + eval_S3
    elif count_S1 <0:
        eval_S1 = count_S1 * S1[-1] * fee_buy
        eval_S2 = count_S2 * S2[-1] * fee_sell
        eval_S3 = count_S3 * S3[-1] * fee_sell
        cash += eval_S1 + eval_S2 + eval_S3

    return cash

# %% [markdown]
# ### 알고리즘 1-1번

# %%
#Trade using a simple strategy
def algo_1( start, finish , money):

    # date = [x for x in calender if finish >= x >= start ]
    
    df = get_data(temp,start, finish)
    
    fee_buy = (1.00015)
    fee_sell = (1-0.00015)
    
    # Simulate trading
    S1 = df['kodex_active']
    S2 = df['kodex200']
    S3 = df['kodex_inv']
    S4 = df['tiger_active']

    # Start with no money and no positions        
    count_S1 = 0 
    count_S2 = 0    
    count_S3 = 0  
    count_S4 = 0

    spread_kodex = df['dayret_spread_kodex']
    spread_tiger = df['dayret_spread_tiger']   
    
    cash = money
    
    #start trading
    for i in range(1,len(df)):        
        
        money = cash
        print(i,'번째거래')
        
        if cash < min(S1[i],S2[i],S3[i],S4[i]) :
            print('금액부족')
            continue  
        
        # buy short if the z-score is > 1
        if  spread_kodex[i] > threshold:   # sell S1  buy S2

            count_S1 -= lev
            count_S2 += lev

            cash +=  S1[i] * lev * fee_sell - S2[i] * lev * fee_buy

            eval_S1 = count_S1 * S1[i] *fee_buy
            eval_S2 = count_S2 * S2[i] *fee_sell
            eval_total = eval_S1+ eval_S2 

            print( '-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S2[i], '  /  spread :',spread_kodex[i])
            print('[sell_INFO]    kodex_active  매도금액 : ',S1[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',S2[i]*lev* fee_buy,
                    'kodex_active : ',count_S1,'주  /  kodex_x2 : ',count_S2,'주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
        elif  spread_tiger[i] > threshold:   # sell S1  buy S2

            count_S4 -= lev
            count_S2 += lev

            cash +=  S4[i] * lev * fee_sell - S2[i] * lev * fee_buy

            eval_S4 = count_S4 * S4[i] *fee_buy
            eval_S2 = count_S2 * S2[i] *fee_sell
            eval_total = eval_S4+ eval_S2 

            print( '-----------',' tiger_active 현재가 :',S4[i],' /  kodex_x2 현재가 :',S2[i], '  /  spread :',spread_tiger[i])
            print('[sell_INFO]    tiger_active  매도금액 : ',S4[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',S2[i]*lev* fee_buy,
                    'tiger_active : ',count_S4,'주  /  kodex_x2 : ',count_S2,'주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

            

        elif  spread_kodex[i] < - threshold :   # buy S1  sell S2

            count_S1 += lev
            count_S3 += lev

            cash -=  S1[i] * lev * fee_buy + S3[i] * lev * fee_buy

            eval_S1 = count_S1 * S1[i] *fee_sell
            eval_S3 = count_S3 * S3[i] *fee_sell
            eval_total = eval_S1+ eval_S3 

            print( '-----------',' kodex_active 현재가 :',S1[i],' / kodex_inv 현재가 :',S3[i], '  /  spread :',spread_kodex[i])
            print('[buy_INFO]   kodex_active 매수금액 :',S1[i]* lev*fee_buy,'/  kodex_inv 매수금액 :',S3[i]*lev* fee_buy,
                    'kodex_active : ',count_S1,'주  /  kodex_inv : ',count_S3,'주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

        elif  spread_tiger[i] < - threshold :   # buy S1  sell S2

            count_S4 += lev
            count_S3 += lev

            cash -=  S4[i] * lev * fee_buy + S3[i] * lev * fee_buy

            eval_S4 = count_S4 * S4[i] *fee_sell
            eval_S3 = count_S3 * S3[i] *fee_sell
            eval_total = eval_S4+ eval_S3 

            print( '-----------',' tiger_active 현재가 :',S4[i],' / kodex_inv 현재가 :',S3[i], '  /  spread :',spread_tiger[i])
            print('[buy_INFO]   tiger_active 매수금액 :',S4[i]* lev*fee_buy,'/  kodex_inv 매수금액 :',S3[i]*lev* fee_buy,
                    'tiger_active : ',count_S4,'주  /  kodex_inv : ',count_S3,'주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
    

        # Clear positions if the z-score between -.5 and .5        
        # -0.5~0.5 사이인 경우 수익일 경우 이익 실현
        elif abs(spread_kodex[i]) < threshold :           

            if count_S1 > 0 :
                eval_S1 = count_S1 * S1[i] * fee_sell
                eval_S3 = count_S3 * S3[i] * fee_sell
                eval_total = eval_S1 + eval_S3
                    
                temp_cash = cash + eval_S1 + eval_S3 
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0 
                    count_S3 = 0 
                    print('-----------','kodex_active 현재가 :',S1[i],' /  kodex_inv 현재가 :',S3[i])
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S1,'원',' / 총매도금액 :', eval_S3  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:',count_S3,'주' ) 
            elif count_S1 < 0 :
                eval_S1 = count_S1 * S1[i] * fee_buy
                eval_S2 = count_S2 * S2[i] * fee_sell
                eval_total = eval_S1 + eval_S2
                    
                temp_cash = cash + eval_S1 + eval_S2 
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0 
                    count_S2 = 0 
                    print('-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S2[i])
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S1,'원',' / 총매도금액 :', eval_S2  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:',count_S2,'주' ) 

        elif abs(spread_tiger[i]) < threshold :  
            if count_S4 > 0 :
                eval_S4 = count_S4 * S4[i] * fee_sell
                eval_S3 = count_S3 * S3[i] * fee_sell
                eval_total = eval_S4 + eval_S3
                    
                temp_cash = cash + eval_S4 + eval_S3 
                if temp_cash > money :
                    cash = temp_cash
                    count_S4 = 0 
                    count_S3 = 0 
                    print('-----------','tiger_active 현재가 :',S4[i],' /  kodex_inv 현재가 :',S3[i])
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S4,'원',' / 총매도금액 :', eval_S3  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S4,'주  /  ','active:',count_S3,'주' ) 
            elif count_S4 < 0 :
                eval_S4 = count_S4 * S4[i] * fee_buy
                eval_S2 = count_S2 * S2[i] * fee_sell
                eval_total = eval_S4 + eval_S2
                    
                temp_cash = cash + eval_S4 + eval_S2 
                if temp_cash > money :
                    cash = temp_cash
                    count_S4 = 0 
                    count_S2 = 0 
                    print('-----------',' tiger_active 현재가 :',S4[i],' /  kodex_x2 현재가 :',S2[i])
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S4,'원',' / 총매도금액 :', eval_S2  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S4,'주  /  ','active:',count_S2,'주' ) 
        else:
            pass  

            
    if count_S1 > 0 :
        eval_S1 = count_S1 * S1[-1] * fee_sell
        eval_S2 = count_S2 * S2[-1] * fee_buy
        cash += eval_S1 + eval_S2 
    elif count_S1 <0:
        eval_S1 = count_S1 * S1[-1] * fee_buy
        eval_S2 = count_S2 * S2[-1] * fee_sell
        cash += eval_S1 + eval_S2 
    
    if count_S4 > 0 :
        eval_S4 = count_S4 * S4[-1] * fee_sell
        eval_S3 = count_S3 * S3[-1] * fee_buy
        cash += eval_S4 + eval_S3 
    elif count_S4 <0:
        eval_S4 = count_S4 * S4[-1] * fee_buy
        eval_S3 = count_S3 * S3[-1] * fee_sell
        cash += eval_S4 + eval_S3 

    return cash

# %% [markdown]
# ### 알고리즘 1-2번

# %%
#Trade using a simple strategy
def algo_1_2( start, finish , money):

    # date = [x for x in calender if finish >= x >= start ]
    
    df = get_data(temp,start, finish)
    
    fee_buy = (1.00015)
    fee_sell = (1-0.00015)
    
    # Simulate trading
    S1 = df['kodex_active']
    S2 = df['kodex200']
    S3 = df['kodex200']
    S4 = df['tiger_active']

    # Start with no money and no positions        
    count_S1 = 0 
    count_S2 = 0    
    count_S3 = 0  
    count_S4 = 0

    spread_kodex = df['dayret_spread_kodex']
    spread_tiger = df['dayret_spread_tiger']   
    
    cash = money
    
    #start trading
    for i in range(1,len(df)):        
        
        money = cash
        print(i,'번째거래')
        
        if cash < min(S1[i],S2[i],S3[i],S4[i]) :
            print('금액부족')
            continue  
        
        # buy short if the z-score is > 1
        if  spread_kodex[i] > threshold:   # sell S1  buy S2

            count_S1 -= lev
            count_S2 += lev

            cash +=  S1[i] * lev * fee_sell - S2[i] * lev * fee_buy

            eval_S1 = count_S1 * S1[i] *fee_buy
            eval_S2 = count_S2 * S2[i] *fee_sell
            eval_total = eval_S1+ eval_S2 

            print( '-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S2[i], '  /  spread :',spread_kodex[i])
            print('[sell_INFO]    kodex_active  매도금액 : ',S1[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',S2[i]*lev* fee_buy,
                    'kodex_active : ',count_S1,'주  /  kodex_x2 : ',count_S2,'주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
        elif  spread_tiger[i] > threshold:   # sell S1  buy S2

            count_S4 -= lev
            count_S3 += lev

            cash +=  S4[i] * lev * fee_sell - S3[i] * lev * fee_buy

            eval_S4 = count_S4 * S4[i] *fee_buy
            eval_S3 = count_S2 * S3[i] *fee_sell
            eval_total = eval_S4+ eval_S3 

            print( '-----------',' tiger_active 현재가 :',S4[i],' /  kodex_x2 현재가 :',S3[i], '  /  spread :',spread_tiger[i])
            print('[sell_INFO]    tiger_active  매도금액 : ',S4[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',S3[i]*lev* fee_buy,
                    'tiger_active : ',count_S4,'주  /  kodex_x2 : ',count_S3,'주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

        
        elif  spread_kodex[i] < - threshold :   # buy S1  sell S2

            count_S1 += lev
            count_S2 -= lev

            cash +=  -S1[i] * lev * fee_buy + S2[i] * lev * fee_sell

            eval_S1 = count_S1 * S1[i] *fee_sell
            eval_S2 = count_S2 * S2[i] *fee_buy
            eval_total = eval_S1+ eval_S2

            print( '-----------',' kodex_active 현재가 :',S1[i],' / kodex_inv 현재가 :',S2[i], '  /  spread :',spread_kodex[i])
            print('[buy_INFO]   kodex_active 매수금액 :',S1[i]* lev*fee_buy,'/  kodex_inv 매수금액 :',S2[i]*lev* fee_sell,
                    'kodex_active : ',count_S1,'주  /  kodex_inv : ',count_S2,'주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

        elif  spread_tiger[i] < - threshold :   # buy S1  sell S2

            count_S4 += lev
            count_S3 -= lev

            cash +=  -S4[i] * lev * fee_buy + S3[i] * lev * fee_sell

            eval_S4 = count_S4 * S4[i] *fee_sell
            eval_S3 = count_S3 * S3[i] *fee_buy
            eval_total = eval_S4+ eval_S3 

            print( '-----------',' tiger_active 현재가 :',S4[i],' / kodex_inv 현재가 :',S3[i], '  /  spread :',spread_tiger[i])
            print('[buy_INFO]   tiger_active 매수금액 :',S4[i]* lev*fee_buy,'/  kodex_inv 매수금액 :',S3[i]*lev* fee_sell,
                    'tiger_active : ',count_S4,'주  /  kodex_inv : ',count_S3,'주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
    

        # Clear positions if the z-score between -.5 and .5        
        # -0.5~0.5 사이인 경우 수익일 경우 이익 실현
        elif abs(spread_kodex[i]) < threshold :           

            if count_S1 > 0 :
                eval_S1 = count_S1 * S1[i] * fee_sell
                eval_S2 = count_S2 * S2[i] * fee_buy
                eval_total = eval_S1 + eval_S2
                    
                temp_cash = cash + eval_S1 + eval_S2
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0 
                    count_S2 = 0 
                    print('-----------','kodex_active 현재가 :',S1[i],' /  kodex_inv 현재가 :',S2[i])
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S1,'원',' / 총매도금액 :', eval_S2  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:',count_S2,'주' ) 
            elif count_S1 < 0 :
                eval_S1 = count_S1 * S1[i] * fee_buy
                eval_S2 = count_S2 * S2[i] * fee_sell
                eval_total = eval_S1 + eval_S2
                    
                temp_cash = cash + eval_S1 + eval_S2 
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0 
                    count_S2 = 0 
                    print('-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :',S2[i])
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S1,'원',' / 총매도금액 :', eval_S2  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:',count_S2,'주' ) 

        elif abs(spread_tiger[i]) < threshold :  
            if count_S4 > 0 :
                eval_S4 = count_S4 * S4[i] * fee_sell
                eval_S3 = count_S3 * S3[i] * fee_buy
                eval_total = eval_S4 + eval_S3
                    
                temp_cash = cash + eval_S4 + eval_S3 
                if temp_cash > money :
                    cash = temp_cash
                    count_S4 = 0 
                    count_S3 = 0 
                    print('-----------','tiger_active 현재가 :',S4[i],' /  kodex_inv 현재가 :',S3[i])
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S4,'원',' / 총매도금액 :', eval_S3  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S4,'주  /  ','active:',count_S3,'주' ) 
            elif count_S4 < 0 :
                eval_S4 = count_S4 * S4[i] * fee_buy
                eval_S3 = count_S3 * S3[i] * fee_sell
                eval_total = eval_S4 + eval_S3
                    
                temp_cash = cash + eval_S4 + eval_S3
                if temp_cash > money :
                    cash = temp_cash
                    count_S4 = 0 
                    count_S3 = 0 
                    print('-----------',' tiger_active 현재가 :',S4[i],' /  kodex_x2 현재가 :',S3[i])
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S4,'원',' / 총매도금액 :', eval_S3  ,'원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S4,'주  /  ','active:',count_S3,'주' ) 
        else:
            pass  

            
    if count_S1 > 0 :
        eval_S1 = count_S1 * S1[-1] * fee_sell
        eval_S2 = count_S2 * S2[-1] * fee_buy
        cash += eval_S1 + eval_S2 
    elif count_S1 <0:
        eval_S1 = count_S1 * S1[-1] * fee_buy
        eval_S2 = count_S2 * S2[-1] * fee_sell
        cash += eval_S1 + eval_S2 
    
    if count_S4 > 0 :
        eval_S4 = count_S4 * S4[-1] * fee_sell
        eval_S3 = count_S3 * S3[-1] * fee_buy
        cash += eval_S4 + eval_S3 
    elif count_S4 <0:
        eval_S4 = count_S4 * S4[-1] * fee_buy
        eval_S3 = count_S3 * S3[-1] * fee_sell
        cash += eval_S4 + eval_S3 

    return cash

# %% [markdown]
# ### 알고리즘 2번

# %%
##Trade using a simple strategy
def algo_2( start, finish , money):

    # date = [x for x in calender if finish >= x >= start ]
    
    df = get_data(temp,start, finish)
    
    fee_buy = (1.00015)
    fee_sell = (1-0.00015)
    
    # Simulate trading
    S1 = df['kodex_active']
    S4 = df['tiger_active']

    # Start with no money and no positions        
    count_S1 = 0
    count_S4 = 0

    spread_kodex = df['dayret_spread_kodex']
    spread_tiger = df['dayret_spread_tiger']   
    
    cash = money
    
    #start trading
    for i in range(1,len(df)):        
        
        money = cash
        print(i,'번째거래')
        
        if cash < min(S1[i],S4[i]) :
            print('금액부족')
            continue  
        
        # buy short if the z-score is > 1
        if  spread_kodex[i] > threshold:   # sell S1  buy S2

            count_S1 -= lev

            cash +=  S1[i] * lev * fee_sell 

            eval_S1 = count_S1 * S1[i] *fee_buy
            eval_total = eval_S1

            print( '-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :''  /  spread :',spread_kodex[i])
            print('[sell_INFO]    kodex_active  매도금액 : ',S1[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',
                    'kodex_active : ',count_S1,'주  /  kodex_x2 : ''주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
        elif  spread_tiger[i] > threshold:   # sell S1  buy S2

            count_S4 -= lev

            cash +=  S4[i] * lev * fee_sell 

            eval_S4 = count_S4 * S4[i] *fee_buy
            eval_total = eval_S4

            print( '-----------',' tiger_active 현재가 :',S4[i],' /  kodex_x2 현재가 :' '  /  spread :',spread_tiger[i])
            print('[sell_INFO]    tiger_active  매도금액 : ',S4[i]* lev*fee_sell,'/  kodex_x2 매수금액 :',
                    'tiger_active : ',count_S4,'주  /  kodex_x2 : ''주')
            print('[sell]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

            

        elif  spread_kodex[i] < - threshold :   # buy S1  sell S2

            count_S1 += lev

            cash -=  S1[i] * lev * fee_buy 

            eval_S1 = count_S1 * S1[i] *fee_sell
            eval_total = eval_S1

            print( '-----------',' kodex_active 현재가 :',S1[i],' / kodex_inv 현재가 :', '  /  spread :',spread_kodex[i])
            print('[buy_INFO]   kodex_active 매수금액 :',S1[i]* lev*fee_buy,'/  kodex_inv 매수금액 :',
                    'kodex_active : ',count_S1,'주  /  kodex_inv : ''주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )

        elif  spread_tiger[i] < - threshold :   # buy S1  sell S2

            count_S4 += lev

            cash -=  S4[i] * lev * fee_buy 

            eval_S4 = count_S4 * S4[i] *fee_sell
            eval_total = eval_S4

            print( '-----------',' tiger_active 현재가 :',S1[i],' / kodex_inv 현재가 :' '  /  spread :',spread_tiger[i])
            print('[buy_INFO]   tiger_active 매수금액 :',S1[i]* lev*fee_buy,'/  kodex_inv 매수금액 :',
                    'tiger_active : ',count_S1,'주  /  kodex_inv : ''주')
            print('[buy]' ,'잔고: ',round(eval_total + cash,2),'원  ', ' / 평가금액 :',eval_total,'/ 예수금 :',cash )
    

        # Clear positions if the z-score between -.5 and .5        
        # -0.5~0.5 사이인 경우 수익일 경우 이익 실현
        elif abs(spread_kodex[i]) < threshold :           

            if count_S1 > 0 :
                eval_S1 = count_S1 * S1[i] * fee_sell
                eval_total = eval_S1 
                    
                temp_cash = cash + eval_S1  
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0
                    print('-----------','kodex_active 현재가 :',S1[i],' /  kodex_inv 현재가 :')
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S1,'원',' / 총매도금액 :''원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:','주' ) 
            elif count_S1 < 0 :
                eval_S1 = -count_S1 * S1[i] * fee_buy
                eval_total = eval_S1 
                temp_cash = cash + eval_S1 
                if temp_cash > money :
                    cash = temp_cash
                    count_S1 = 0
                    print('-----------',' kodex_active 현재가 :',S1[i],' /  kodex_x2 현재가 :')
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S1,'원',' / 총매도금액 : 원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S1,'주  /  ','active:','주' ) 

        elif abs(spread_tiger[i]) < threshold :  
            if count_S4 > 0 :
                eval_S4 = count_S4 * S4[i] * fee_sell
                eval_total = eval_S4 
                    
                temp_cash = cash + eval_S4 
                if temp_cash > money :
                    cash = temp_cash
                    count_S4 = 0
                    print('-----------','tiger_active 현재가 :',S4[i],' /  kodex_inv 현재가 :')
                    print('[EXIT_INFO]' , '총매도금액 :',eval_S4,'원',' / 총매도금액 :','원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S4,'주  /  ','active:','주' ) 
            elif count_S4 < 0 :
                eval_S4 = -count_S4 * S4[i] * fee_buy
                eval_total = eval_S4 
                    
                temp_cash = cash + eval_S4 
                if temp_cash > money :
                    cash = temp_cash
                    count_S4 = 0
                    print('-----------',' tiger_active 현재가 :',S4[i],' /  kodex_x2 현재가 :')
                    print('[EXIT_INFO]' , '총매수금액 :',eval_S4,'원',' / 총매도금액 :', '원')
                    print('[EXIT]' ,'잔고: ',round(cash,2),'원  ','kodex:',count_S4,'주  /  ','active:','주' ) 
        else:
            pass  

            
    if count_S1 > 0 :
        eval_S1 = count_S1 * S1[-1] * fee_sell
        cash += eval_S1 
    elif count_S1 <0:
        eval_S1 = count_S1 * S1[-1] * fee_buy
        cash += eval_S1 
    if count_S4 > 0 :
        eval_S4 = count_S4 * S4[-1] * fee_sell
        cash += eval_S4 
    elif count_S4 <0:
        eval_S4 = count_S4 * S4[-1] * fee_buy
        cash += eval_S4 

    return cash

# %% [markdown]
# # 시뮬레이션

# %% [markdown]
# ### 임계치에 따른 레버리지 테스트

# %%
lev = 1
thresholde = 0.003
algo_2(20201228,20201228,3000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f6cbb4067175> in <module>()
#       1 lev = 1
#       2 thresholde = 0.003
# ----> 3 algo_2(20201228,20201228,3000000)
#
# NameError: name 'algo_2' is not defined

# %% [markdown]
# ### 지금까지 과거 데이터 기준  임계치,레버리지 테스트

# %%
lev = 1
profits = {}
backtest={}
x = np.linspace(0.0003,0.003,15)
temp_calender = calender[-3:]

# for dates in temp_calender:
#     profits = {}
for threshold in x:
    for lev in range(1,5):
        ret = algo_1_2(20201229,20201229,1500000)
        profits[ret] = [threshold,lev]
maxprofit = max(profits.keys())
# backtest[dates] = maxprofit, profits[maxprofit]
print(maxprofit,profits[maxprofit])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [sell] 잔고:  1290107.49 원    / 평가금액 : 78832.13775 / 예수금 : 1211275.3562499997
# 43 번째거래
# -----------  kodex_active 현재가 : 12270.0  /  kodex_x2 현재가 : 38560   /  spread : 0.003503723343511362
# [sell_INFO]    kodex_active  매도금액 :  12268.1595 /  kodex_x2 매수금액 : 38565.78400000001 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1290107.23 원    / 평가금액 : 105129.502 / 예수금 : 1184977.7317499998
# 44 번째거래
# -----------  kodex_active 현재가 : 12270.0  /  kodex_x2 현재가 : 38545   /  spread : 0.003892803174630737
# [sell_INFO]    kodex_active  매도금액 :  12268.1595 /  kodex_x2 매수금액 : 38550.78175 kodex_active :  -5 주  /  kodex_x2 :  5 주
# [sell] 잔고:  1290032.0 원    / 평가금액 : 131336.88874999998 / 예수금 : 1158695.1094999998
# 45 번째거래
# -----------  kodex_active 현재가 : 12250.0  /  kodex_x2 현재가 : 38550   /  spread : 0.0021317713444336025
# [sell_INFO]    kodex_active  매도금액 :  12248.1625 /  kodex_x2 매수금액 : 38555.7825 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1290141.77 원    / 평가금액 : 157754.27999999997 / 예수금 : 1132387.4894999997
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  24426.3355 /  kodex_x2 매수금액 : 76721.5065 kodex_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1499969.66 원    / 평가금액 : 52264.829 / 예수금 : 1447704.829
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  24416.337 /  kodex_x2 매수금액 : 76601.4885 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1499829.37 원    / 평가금액 : 104309.69700000001 / 예수금 : 1395519.6775
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  24446.3325 /  kodex_x2 매수금액 : 76701.5035 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1499938.99 원    / 평가금액 : 156674.487 / 예수금 : 1343264.5065
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  24466.3295 /  kodex_x2 매수금액 : 76811.52 kodex_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1500178.55 원    / 평가금액 : 209259.23799999995 / 예수금 : 1290919.3159999999
# 5 번째거래
# -----------  kodex_active 현재가 : 12275.0  /  kodex_x2 현재가 : 38600   /  spread : 0.0028743315728351135
# [sell_INFO]    kodex_active  매도금액 :  24546.3175 /  kodex_x2 매수금액 : 77211.58 kodex_active :  -10 주  /  kodex_x2 :  10 주
# [sell] 잔고:  1501427.74 원    / 평가금액 : 263173.6875 / 예수금 : 1238254.0535
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  24576.313000000002 /  kodex_x2 매수금액 : 77211.58 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1501247.18 원    / 평가금액 : 315628.39800000004 / 예수금 : 1185618.7865
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  24576.313000000002 /  kodex_x2 매수금액 : 77261.58750000001 kodex_active :  -14 주  /  kodex_x2 :  14 주
# [sell] 잔고:  1501516.59 원    / 평가금액 : 368583.07849999995 / 예수금 : 1132933.5119999999
# 8 번째거래
# -----------  kodex_active 현재가 : 12260.0  /  kodex_x2 현재가 : 38580   /  spread : 0.00216985739351842
# [sell_INFO]    kodex_active  매도금액 :  24516.322 /  kodex_x2 매수금액 : 77171.57400000001 kodex_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1501276.24 원    / 평가금액 : 420997.98400000005 / 예수금 : 1080278.2599999998
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77261.58750000001 tiger_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1620916.6 원    / 평가금액 : 593313.6115 / 예수금 : 1027602.9839999997
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77261.58750000001 kodex_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1448730.22 원    / 평가금액 : 473802.516 / 예수금 : 974927.7079999996
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77271.589 kodex_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  1448789.66 원    / 평가금액 : 526547.225 / 예수금 : 922242.4304999997
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  24576.313000000002 /  kodex_x2 매수금액 : 77291.592 kodex_active :  -22 주  /  kodex_x2 :  22 주
# [sell] 잔고:  1449059.08 원    / 평가금액 : 579531.931 / 예수금 : 869527.1514999997
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77261.58750000001 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1448588.56 원    / 평가금액 : 631736.6880000001 / 예수금 : 816851.8754999996
# 14 번째거래
# -----------  kodex_active 현재가 : 12255.0  /  kodex_x2 현재가 : 38540   /  spread : 0.0027992883568913763
# [sell_INFO]    kodex_active  매도금액 :  24506.3235 /  kodex_x2 매수금액 : 77091.562 kodex_active :  -26 주  /  kodex_x2 :  26 주
# [sell] 잔고:  1447478.54 원    / 평가금액 : 683211.8995 / 예수금 : 764266.6369999996
# 15 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  24556.316 /  kodex_x2 매수금액 : 77251.58600000001 kodex_active :  -28 주  /  kodex_x2 :  28 주
# [sell] 잔고:  1448877.59 원    / 평가금액 : 737306.22 / 예수금 : 711571.3669999996
# 16 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  24556.316 /  kodex_x2 매수금액 : 77251.58600000001 kodex_active :  -30 주  /  kodex_x2 :  30 주
# [sell] 잔고:  1448847.05 원    / 평가금액 : 789970.95 / 예수금 : 658876.0969999996
# 17 번째거래
# -----------  kodex_active 현재가 : 12240.0  /  kodex_x2 현재가 : 38525   /  spread : 0.001963830241036465
# [sell_INFO]    kodex_active  매도금액 :  24476.328 /  kodex_x2 매수금액 : 77061.55750000001 kodex_active :  -32 주  /  kodex_x2 :  32 주
# [sell] 잔고:  1447167.2 원    / 평가금액 : 840876.328 / 예수금 : 606290.8674999996
# 18 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38440   /  spread : 0.00212805497064808
# [sell_INFO]    kodex_active  매도금액 :  24426.3355 /  kodex_x2 매수금액 : 76891.532 kodex_active :  -34 주  /  kodex_x2 :  34 주
# [sell] 잔고:  1445217.33 원    / 평가금액 : 891391.6595 / 예수금 : 553825.6709999996
# 19 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38370   /  spread : 0.0019019735973550764
# [sell_INFO]    kodex_active  매도금액 :  24376.343 /  kodex_x2 매수금액 : 76751.51100000001 kodex_active :  -36 주  /  kodex_x2 :  36 주
# [sell] 잔고:  1443657.48 원    / 평가금액 : 942206.9759999998 / 예수금 : 501450.5029999996
# 20 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76811.52 tiger_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1782380.62 원    / 평가금액 : 1333305.3080000002 / 예수금 : 449075.31699999963
# 21 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38465   /  spread : 0.0014779021618417983
# [sell_INFO]    kodex_active  매도금액 :  24426.3355 /  kodex_x2 매수금액 : 76941.53950000001 kodex_active :  -38 주  /  kodex_x2 :  38 주
# [sell] 잔고:  1393771.24 원    / 평가금액 : 997211.1239999998 / 예수금 : 396560.1129999996
# 22 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38395   /  spread : 0.0016607232484127585
# [sell_INFO]    kodex_active  매도금액 :  24386.3415 /  kodex_x2 매수금액 : 76801.5185 kodex_active :  -40 주  /  kodex_x2 :  40 주
# [sell] 잔고:  1391841.4 원    / 평가금액 : 1047696.4600000001 / 예수금 : 344144.9359999996
# 23 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38400   /  spread : 0.0015305064372384512
# [sell_INFO]    kodex_active  매도금액 :  24386.3415 /  kodex_x2 매수금액 : 76811.52 kodex_active :  -42 주  /  kodex_x2 :  42 주
# [sell] 잔고:  1392011.01 원    / 평가금액 : 1100291.2515 / 예수금 : 291719.7574999996
# 24 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38385   /  spread : 0.0019212077510578213
# [sell_INFO]    kodex_active  매도금액 :  24386.3415 /  kodex_x2 매수금액 : 76781.51550000001 kodex_active :  -44 주  /  kodex_x2 :  44 주
# [sell] 잔고:  1391350.76 원    / 평가금액 : 1152026.1719999998 / 예수금 : 239324.5834999996
# 25 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38470   /  spread : 0.0038217911867632487
# [sell_INFO]    tiger_active  매도금액 :  24456.331000000002 /  kodex_x2 매수금액 : 76951.54100000001 tiger_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1805864.46 원    / 평가금액 : 1619035.091 / 예수금 : 186829.37349999958
# 26 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38435   /  spread : 0.0030764669228764852
# [sell_INFO]    kodex_active  매도금액 :  24446.3325 /  kodex_x2 매수금액 : 76881.53050000001 kodex_active :  -46 주  /  kodex_x2 :  46 주
# [sell] 잔고:  1339704.62 원    / 평가금액 : 1205310.446 / 예수금 : 134394.17549999958
# 27 번째거래
# -----------  tiger_active 현재가 : 12235  /  kodex_x2 현재가 : 38435   /  spread : 0.005140752345425683
# [sell_INFO]    tiger_active  매도금액 :  24466.3295 /  kodex_x2 매수금액 : 76881.53050000001 tiger_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1751829.09 원    / 평가금액 : 1669850.1165 / 예수금 : 81978.97449999957
# 28 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38375   /  spread : 0.0017716719488548582
# [sell_INFO]    kodex_active  매도금액 :  24376.343 /  kodex_x2 매수금액 : 76761.51250000001 kodex_active :  -48 주  /  kodex_x2 :  48 주
# [sell] 잔고:  1286109.74 원    / 평가금액 : 1256515.932 / 예수금 : 29593.804999999564
# 29 번째거래
# -----------  kodex_active 현재가 : 12180.0  /  kodex_x2 현재가 : 38355   /  spread : 0.0014722992335272512
# [sell_INFO]    kodex_active  매도금액 :  24356.346 /  kodex_x2 매수금액 : 76721.5065 kodex_active :  -50 주  /  kodex_x2 :  50 주
# [sell] 잔고:  1285599.63 원    / 평가금액 : 1308370.9875 / 예수금 : -22771.355500000434
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  36639.50325 /  kodex_x2 매수금액 : 115082.25975000001 kodex_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1499954.49 원    / 평가금액 : 78397.2435 / 예수금 : 1421557.2434999999
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  36624.5055 /  kodex_x2 매수금액 : 114902.23275000001 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1499744.06 원    / 평가금액 : 156464.5455 / 예수금 : 1343279.5162499999
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  36669.49875 /  kodex_x2 매수금액 : 115052.25525000002 kodex_active :  -9 주  /  kodex_x2 :  9 주
# [sell] 잔고:  1499908.49 원    / 평가금액 : 235011.73049999998 / 예수금 : 1264896.7597499997
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  36699.49425 /  kodex_x2 매수금액 : 115217.28000000001 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1500267.83 원    / 평가금액 : 313888.85699999996 / 예수금 : 1186378.9739999997
# 5 번째거래
# -----------  kodex_active 현재가 : 12275.0  /  kodex_x2 현재가 : 38600   /  spread : 0.0028743315728351135
# [sell_INFO]    kodex_active  매도금액 :  36819.47625 /  kodex_x2 매수금액 : 115817.37000000001 kodex_active :  -15 주  /  kodex_x2 :  15 주
# [sell] 잔고:  1502141.61 원    / 평가금액 : 394760.53125 / 예수금 : 1107381.0802499996
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  36864.4695 /  kodex_x2 매수금액 : 115817.37000000001 kodex_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1501870.78 원    / 평가금액 : 473442.597 / 예수금 : 1028428.1797499997
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  36864.4695 /  kodex_x2 매수금액 : 115892.38125 kodex_active :  -21 주  /  kodex_x2 :  21 주
# [sell] 잔고:  1502274.89 원    / 평가금액 : 552874.61775 / 예수금 : 949400.2679999997
# 8 번째거래
# -----------  kodex_active 현재가 : 12260.0  /  kodex_x2 현재가 : 38580   /  spread : 0.00216985739351842
# [sell_INFO]    kodex_active  매도금액 :  36774.483 /  kodex_x2 매수금액 : 115757.361 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1501914.37 원    / 평가금액 : 631496.9759999999 / 예수금 : 870417.3899999997
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115892.38125 tiger_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1681374.89 원    / 평가금액 : 889970.41725 / 예수금 : 791404.4759999997
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115892.38125 kodex_active :  -27 주  /  kodex_x2 :  27 주
# [sell] 잔고:  1423095.34 원    / 평가금액 : 710703.774 / 예수금 : 712391.5619999997
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115907.38350000001 kodex_active :  -30 주  /  kodex_x2 :  30 주
# [sell] 잔고:  1423184.48 원    / 평가금액 : 789820.8375 / 예수금 : 633363.6457499997
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  36864.4695 /  kodex_x2 매수금액 : 115937.388 kodex_active :  -33 주  /  kodex_x2 :  33 주
# [sell] 잔고:  1423588.62 원    / 평가금액 : 869297.8965 / 예수금 : 554290.7272499996
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115892.38125 kodex_active :  -36 주  /  kodex_x2 :  36 주
# [sell] 잔고:  1422882.85 원    / 평가금액 : 947605.032 / 예수금 : 475277.81324999966
# 14 번째거래
# -----------  kodex_active 현재가 : 12255.0  /  kodex_x2 현재가 : 38540   /  spread : 0.0027992883568913763
# [sell_INFO]    kodex_active  매도금액 :  36759.48525 /  kodex_x2 매수금액 : 115637.34300000001 kodex_active :  -39 주  /  kodex_x2 :  39 주
# [sell] 잔고:  1421217.8 원    / 평가금액 : 1024817.84925 / 예수금 : 396399.95549999963
# 15 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  36834.474 /  kodex_x2 매수금액 : 115877.37900000002 kodex_active :  -42 주  /  kodex_x2 :  42 주
# [sell] 잔고:  1423316.38 원    / 평가금액 : 1105959.33 / 예수금 : 317357.0504999996
# 16 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  36834.474 /  kodex_x2 매수금액 : 115877.37900000002 kodex_active :  -45 주  /  kodex_x2 :  45 주
# [sell] 잔고:  1423270.57 원    / 평가금액 : 1184956.4249999998 / 예수금 : 238314.14549999958
# 17 번째거래
# -----------  kodex_active 현재가 : 12240.0  /  kodex_x2 현재가 : 38525   /  spread : 0.001963830241036465
# [sell_INFO]    kodex_active  매도금액 :  36714.492 /  kodex_x2 매수금액 : 115592.33625000001 kodex_active :  -48 주  /  kodex_x2 :  48 주
# [sell] 잔고:  1420750.79 원    / 평가금액 : 1261314.492 / 예수금 : 159436.30124999955
# 18 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38440   /  spread : 0.00212805497064808
# [sell_INFO]    kodex_active  매도금액 :  36639.50325 /  kodex_x2 매수금액 : 115337.29800000001 kodex_active :  -51 주  /  kodex_x2 :  51 주
# [sell] 잔고:  1417826.0 원    / 평가금액 : 1337087.48925 / 예수금 : 80738.50649999955
# 19 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38370   /  spread : 0.0019019735973550764
# [sell_INFO]    kodex_active  매도금액 :  36564.5145 /  kodex_x2 매수금액 : 115127.26650000001 kodex_active :  -54 주  /  kodex_x2 :  54 주
# [sell] 잔고:  1415486.22 원    / 평가금액 : 1413310.464 / 예수금 : 2175.7544999995444
# 20 번째거래
# 금액부족
# 21 번째거래
# 금액부족
# 22 번째거래
# 금액부족
# 23 번째거래
# 금액부족
# 24 번째거래
# 금액부족
# 25 번째거래
# 금액부족
# 26 번째거래
# 금액부족
# 27 번째거래
# 금액부족
# 28 번째거래
# 금액부족
# 29 번째거래
# 금액부족
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  48852.671 /  kodex_x2 매수금액 : 153443.013 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1499939.32 원    / 평가금액 : 104529.658 / 예수금 : 1395409.658
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  48832.674 /  kodex_x2 매수금액 : 153202.977 kodex_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1499658.75 원    / 평가금액 : 208619.39400000003 / 예수금 : 1291039.355
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  48892.665 /  kodex_x2 매수금액 : 153403.007 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1499877.99 원    / 평가금액 : 313348.974 / 예수금 : 1186529.013
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  48932.659 /  kodex_x2 매수금액 : 153623.04 kodex_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1500357.11 원    / 평가금액 : 418518.4759999999 / 예수금 : 1081838.632
# 5 번째거래
# -----------  kodex_active 현재가 : 12275.0  /  kodex_x2 현재가 : 38600   /  spread : 0.0028743315728351135
# [sell_INFO]    kodex_active  매도금액 :  49092.635 /  kodex_x2 매수금액 : 154423.16 kodex_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  1502855.48 원    / 평가금액 : 526347.375 / 예수금 : 976508.107
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  49152.626000000004 /  kodex_x2 매수금액 : 154423.16 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1502494.37 원    / 평가금액 : 631256.7960000001 / 예수금 : 871237.573
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  49152.626000000004 /  kodex_x2 매수금액 : 154523.17500000002 kodex_active :  -28 주  /  kodex_x2 :  28 주
# [sell] 잔고:  1503033.18 원    / 평가금액 : 737166.1569999999 / 예수금 : 765867.024
# 8 번째거래
# -----------  kodex_active 현재가 : 12260.0  /  kodex_x2 현재가 : 38580   /  spread : 0.00216985739351842
# [sell_INFO]    kodex_active  매도금액 :  49032.644 /  kodex_x2 매수금액 : 154343.14800000002 kodex_active :  -32 주  /  kodex_x2 :  32 주
# [sell] 잔고:  1502552.49 원    / 평가금액 : 841995.9680000001 / 예수금 : 660556.52
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154523.17500000002 tiger_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1741833.19 원    / 평가금액 : 1186627.223 / 예수금 : 555205.968
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154523.17500000002 kodex_active :  -36 주  /  kodex_x2 :  36 주
# [sell] 잔고:  1397460.45 원    / 평가금액 : 947605.032 / 예수금 : 449855.41599999997
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154543.178 kodex_active :  -40 주  /  kodex_x2 :  40 주
# [sell] 잔고:  1397579.31 원    / 평가금액 : 1053094.45 / 예수금 : 344484.8609999999
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  49152.626000000004 /  kodex_x2 매수금액 : 154583.184 kodex_active :  -44 주  /  kodex_x2 :  44 주
# [sell] 잔고:  1398118.16 원    / 평가금액 : 1159063.862 / 예수금 : 239054.3029999999
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154523.17500000002 kodex_active :  -48 주  /  kodex_x2 :  48 주
# [sell] 잔고:  1397177.13 원    / 평가금액 : 1263473.3760000002 / 예수금 : 133703.75099999987
# 14 번째거래
# -----------  kodex_active 현재가 : 12255.0  /  kodex_x2 현재가 : 38540   /  spread : 0.0027992883568913763
# [sell_INFO]    kodex_active  매도금액 :  49012.647 /  kodex_x2 매수금액 : 154183.124 kodex_active :  -52 주  /  kodex_x2 :  52 주
# [sell] 잔고:  1394957.07 원    / 평가금액 : 1366423.799 / 예수금 : 28533.27399999986
# 15 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  49112.632 /  kodex_x2 매수금액 : 154503.17200000002 kodex_active :  -56 주  /  kodex_x2 :  56 주
# [sell] 잔고:  1397755.17 원    / 평가금액 : 1474612.44 / 예수금 : -76857.26600000016
# 16 번째거래
# 금액부족
# 17 번째거래
# 금액부족
# 18 번째거래
# 금액부족
# 19 번째거래
# 금액부족
# 20 번째거래
# 금액부족
# 21 번째거래
# 금액부족
# 22 번째거래
# 금액부족
# 23 번째거래
# 금액부족
# 24 번째거래
# 금액부족
# 25 번째거래
# 금액부족
# 26 번째거래
# 금액부족
# 27 번째거래
# 금액부족
# 28 번째거래
# 금액부족
# 29 번째거래
# 금액부족
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  12213.16775 /  kodex_x2 매수금액 : 38360.75325 kodex_active :  -1 주  /  kodex_x2 :  1 주
# [sell] 잔고:  1499984.83 원    / 평가금액 : 26132.4145 / 예수금 : 1473852.4145
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  12208.1685 /  kodex_x2 매수금액 : 38300.74425 kodex_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1499914.69 원    / 평가금액 : 52154.84850000001 / 예수금 : 1447759.8387499999
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  12223.16625 /  kodex_x2 매수금액 : 38350.75175 kodex_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1499969.5 원    / 평가금액 : 78337.2435 / 예수금 : 1421632.2532499998
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  12233.16475 /  kodex_x2 매수금액 : 38405.76 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1500089.28 원    / 평가금액 : 104629.61899999998 / 예수금 : 1395459.6579999998
# 5 번째거래
# -----------  kodex_active 현재가 : 12275.0  /  kodex_x2 현재가 : 38600   /  spread : 0.0028743315728351135
# [sell_INFO]    kodex_active  매도금액 :  12273.15875 /  kodex_x2 매수금액 : 38605.79 kodex_active :  -5 주  /  kodex_x2 :  5 주
# [sell] 잔고:  1500713.87 원    / 평가금액 : 131586.84375 / 예수금 : 1369127.0267499997
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  12288.156500000001 /  kodex_x2 매수금액 : 38605.79 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1500623.59 원    / 평가금액 : 157814.19900000002 / 예수금 : 1342809.3932499997
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  12288.156500000001 /  kodex_x2 매수금액 : 38630.793750000004 kodex_active :  -7 주  /  kodex_x2 :  7 주
# [sell] 잔고:  1500758.3 원    / 평가금액 : 184291.53924999997 / 예수금 : 1316466.7559999998
# 8 번째거래
# -----------  kodex_active 현재가 : 12260.0  /  kodex_x2 현재가 : 38580   /  spread : 0.00216985739351842
# [sell_INFO]    kodex_active  매도금액 :  12258.161 /  kodex_x2 매수금액 : 38585.787000000004 kodex_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1500638.12 원    / 평가금액 : 210498.99200000003 / 예수금 : 1290139.13
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  12293.15575 /  kodex_x2 매수금액 : 38630.793750000004 tiger_active :  -1 주  /  kodex_x2 :  1 주
# [sell] 잔고:  1560458.3 원    / 평가금액 : 296656.80575 / 예수금 : 1263801.4919999999
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  12293.15575 /  kodex_x2 매수금액 : 38630.793750000004 kodex_active :  -9 주  /  kodex_x2 :  9 주
# [sell] 잔고:  1474365.11 원    / 평가금액 : 236901.258 / 예수금 : 1237463.8539999998
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  12293.15575 /  kodex_x2 매수금액 : 38635.7945 kodex_active :  -10 주  /  kodex_x2 :  10 주
# [sell] 잔고:  1474394.83 원    / 평가금액 : 263273.6125 / 예수금 : 1211121.21525
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  12288.156500000001 /  kodex_x2 매수금액 : 38645.796 kodex_active :  -11 주  /  kodex_x2 :  11 주
# [sell] 잔고:  1474529.54 원    / 평가금액 : 289765.9655 / 예수금 : 1184763.5757499998
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  12293.15575 /  kodex_x2 매수금액 : 38630.793750000004 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1474294.28 원    / 평가금액 : 315868.34400000004 / 예수금 : 1158425.9377499998
# 14 번째거래
# -----------  kodex_active 현재가 : 12255.0  /  kodex_x2 현재가 : 38540   /  spread : 0.0027992883568913763
# [sell_INFO]    kodex_active  매도금액 :  12253.16175 /  kodex_x2 매수금액 : 38545.781 kodex_active :  -13 주  /  kodex_x2 :  13 주
# [sell] 잔고:  1473739.27 원    / 평가금액 : 341605.94975 / 예수금 : 1132133.3184999998
# 15 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  12278.158 /  kodex_x2 매수금액 : 38625.793000000005 kodex_active :  -14 주  /  kodex_x2 :  14 주
# [sell] 잔고:  1474438.79 원    / 평가금액 : 368653.11 / 예수금 : 1105785.6834999998
# 16 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  12278.158 /  kodex_x2 매수금액 : 38625.793000000005 kodex_active :  -15 주  /  kodex_x2 :  15 주
# [sell] 잔고:  1474423.52 원    / 평가금액 : 394985.475 / 예수금 : 1079438.0484999998
# 17 번째거래
# -----------  kodex_active 현재가 : 12240.0  /  kodex_x2 현재가 : 38525   /  spread : 0.001963830241036465
# [sell_INFO]    kodex_active  매도금액 :  12238.164 /  kodex_x2 매수금액 : 38530.778750000005 kodex_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1473583.6 원    / 평가금액 : 420438.164 / 예수금 : 1053145.4337499999
# 18 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38440   /  spread : 0.00212805497064808
# [sell_INFO]    kodex_active  매도금액 :  12213.16775 /  kodex_x2 매수금액 : 38445.766 kodex_active :  -17 주  /  kodex_x2 :  17 주
# [sell] 잔고:  1472608.67 원    / 평가금액 : 445695.82975 / 예수금 : 1026912.8354999998
# 19 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38370   /  spread : 0.0019019735973550764
# [sell_INFO]    kodex_active  매도금액 :  12188.1715 /  kodex_x2 매수금액 : 38375.75550000001 kodex_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1471828.74 원    / 평가금액 : 471103.4879999999 / 예수금 : 1000725.2514999998
# 20 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  12218.167 /  kodex_x2 매수금액 : 38405.76 tiger_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1641190.31 원    / 평가금액 : 666652.6540000001 / 예수금 : 974537.6584999998
# 21 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38465   /  spread : 0.003951771040069019
# [sell_INFO]    tiger_active  매도금액 :  12228.165500000001 /  kodex_x2 매수금액 : 38470.76975000001 tiger_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1603865.7 원    / 평가금액 : 655570.6410000001 / 예수금 : 948295.0542499998
# 22 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38395   /  spread : 0.0016607232484127585
# [sell_INFO]    kodex_active  매도금액 :  12193.17075 /  kodex_x2 매수금액 : 38400.75925 kodex_active :  -19 주  /  kodex_x2 :  19 주
# [sell] 잔고:  1419743.28 원    / 평가금액 : 497655.81850000005 / 예수금 : 922087.4657499999
# 23 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  12218.167 /  kodex_x2 매수금액 : 38405.76 tiger_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1576503.1 원    / 평가금액 : 680603.228 / 예수금 : 895899.8727499999
# 24 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38385   /  spread : 0.0019212077510578213
# [sell_INFO]    kodex_active  매도금액 :  12193.17075 /  kodex_x2 매수금액 : 38390.757750000004 kodex_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  1393350.55 원    / 평가금액 : 523648.25999999995 / 예수금 : 869702.2857499998
# 25 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38470   /  spread : 0.0038217911867632487
# [sell_INFO]    tiger_active  매도금액 :  12228.165500000001 /  kodex_x2 매수금액 : 38475.770500000006 tiger_active :  -5 주  /  kodex_x2 :  5 주
# [sell] 잔고:  1551580.1 원    / 평가금액 : 708125.4175 / 예수금 : 843454.6807499998
# 26 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38435   /  spread : 0.0030764669228764852
# [sell_INFO]    kodex_active  매도금액 :  12223.16625 /  kodex_x2 매수금액 : 38440.765250000004 kodex_active :  -21 주  /  kodex_x2 :  21 주
# [sell] 잔고:  1367487.5 원    / 평가금액 : 550250.421 / 예수금 : 817237.0817499998
# 27 번째거래
# -----------  tiger_active 현재가 : 12235  /  kodex_x2 현재가 : 38435   /  spread : 0.005140752345425683
# [sell_INFO]    tiger_active  매도금액 :  12233.16475 /  kodex_x2 매수금액 : 38440.765250000004 tiger_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1524622.4 원    / 평가금액 : 733592.91825 / 예수금 : 791029.4812499997
# 28 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38375   /  spread : 0.0017716719488548582
# [sell_INFO]    kodex_active  매도금액 :  12188.1715 /  kodex_x2 매수금액 : 38380.756250000006 kodex_active :  -22 주  /  kodex_x2 :  22 주
# [sell] 잔고:  1340740.03 원    / 평가금액 : 575903.1355000001 / 예수금 : 764836.8964999997
# 29 번째거래
# -----------  tiger_active 현재가 : 12205  /  kodex_x2 현재가 : 38355   /  spread : 0.004769364685549761
# [sell_INFO]    tiger_active  매도금액 :  12203.16925 /  kodex_x2 매수금액 : 38360.75325 tiger_active :  -7 주  /  kodex_x2 :  7 주
# [sell] 잔고:  1496914.93 원    / 평가금액 : 758235.61325 / 예수금 : 738679.3124999997
# 30 번째거래
# -----------  tiger_active 현재가 : 12200  /  kodex_x2 현재가 : 38345   /  spread : 0.004620368774274377
# [sell_INFO]    tiger_active  매도금액 :  12198.17 /  kodex_x2 매수금액 : 38350.75175 tiger_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1458375.55 원    / 평가금액 : 745848.8215 / 예수금 : 712526.7307499996
# 31 번째거래
# -----------  tiger_active 현재가 : 12185  /  kodex_x2 현재가 : 38275   /  spread : 0.005217303785308207
# [sell_INFO]    tiger_active  매도금액 :  12183.17225 /  kodex_x2 매수금액 : 38280.74125000001 tiger_active :  -9 주  /  kodex_x2 :  9 주
# [sell] 잔고:  1418671.4 원    / 평가금액 : 732242.24275 / 예수금 : 686429.1617499996
# 32 번째거래
# -----------  kodex_active 현재가 : 12170.0  /  kodex_x2 현재가 : 38240   /  spread : 0.0036537531792713105
# [sell_INFO]    kodex_active  매도금액 :  12168.174500000001 /  kodex_x2 매수금액 : 38245.736000000004 kodex_active :  -23 주  /  kodex_x2 :  23 주
# [sell] 잔고:  1259787.69 원    / 평가금액 : 599436.0855 / 예수금 : 660351.6002499997
# 33 번째거래
# -----------  tiger_active 현재가 : 12165  /  kodex_x2 현재가 : 38325   /  spread : 0.0022691097294941544
# [sell_INFO]    tiger_active  매도금액 :  12163.17525 /  kodex_x2 매수금액 : 38330.748750000006 tiger_active :  -10 주  /  kodex_x2 :  10 주
# [sell] 잔고:  1393858.56 원    / 평가금액 : 759674.53125 / 예수금 : 634184.0267499996
# 34 번째거래
# -----------  tiger_active 현재가 : 12210  /  kodex_x2 현재가 : 38395   /  spread : 0.004136603591992553
# [sell_INFO]    tiger_active  매도금액 :  12208.1685 /  kodex_x2 매수금액 : 38400.75925 tiger_active :  -11 주  /  kodex_x2 :  11 주
# [sell] 잔고:  1356613.83 원    / 평가금액 : 748622.39075 / 예수금 : 607991.4359999996
# 35 번째거래
# -----------  kodex_active 현재가 : 12205.0  /  kodex_x2 현재가 : 38390   /  spread : 0.002610629195253119
# [sell_INFO]    kodex_active  매도금액 :  12203.16925 /  kodex_x2 매수금액 : 38395.7585 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1210056.7 원    / 평가금액 : 628257.858 / 예수금 : 581798.8467499997
# 36 번째거래
# -----------  kodex_active 현재가 : 12220.0  /  kodex_x2 현재가 : 38435   /  spread : 0.0026673853053899004
# [sell_INFO]    kodex_active  매도금액 :  12218.167 /  kodex_x2 매수금액 : 38440.765250000004 kodex_active :  -25 주  /  kodex_x2 :  25 주
# [sell] 잔고:  1210761.29 원    / 평가금액 : 655185.04375 / 예수금 : 555576.2484999996
# 37 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38450   /  spread : 0.0026862737723187917
# [sell_INFO]    kodex_active  매도금액 :  12223.16625 /  kodex_x2 매수금액 : 38455.7675 kodex_active :  -26 주  /  kodex_x2 :  26 주
# [sell] 잔고:  1210996.01 원    / 평가금액 : 681652.3674999999 / 예수금 : 529343.6472499997
# 38 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38440
# [EXIT_INFO] 총매수금액 : -317117.5605 원  / 총매도금액 : 999290.084 원
# [EXIT] 잔고:  1211516.17 원   kodex: 0 주  /   active: 0 주
# 39 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38470   /  spread : 0.0038217911867632487
# [sell_INFO]    tiger_active  매도금액 :  12228.165500000001 /  kodex_x2 매수금액 : 38475.770500000006 tiger_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1038486.55 원    / 평가금액 : -146782.01400000002 / 예수금 : 1185268.5657499996
# 40 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38450   /  spread : 0.0018679431210868267
# [sell_INFO]    kodex_active  매도금액 :  12213.16775 /  kodex_x2 매수금액 : 38455.7675 kodex_active :  -1 주  /  kodex_x2 :  1 주
# [sell] 잔고:  1185253.37 원    / 평가금액 : 26227.40025 / 예수금 : 1159025.9659999995
# 41 번째거래
# -----------  kodex_active 현재가 : 12255.0  /  kodex_x2 현재가 : 38560   /  spread : 0.002280481600767034
# [sell_INFO]    kodex_active  매도금액 :  12253.16175 /  kodex_x2 매수금액 : 38565.78400000001 kodex_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1185308.1 원    / 평가금액 : 52594.7555 / 예수금 : 1132713.3437499995
# 42 번째거래
# -----------  kodex_active 현재가 : 12260.0  /  kodex_x2 현재가 : 38545   /  spread : 0.0030774749598759775
# [sell_INFO]    kodex_active  매도금액 :  12258.161 /  kodex_x2 매수금액 : 38550.78175 kodex_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1185252.86 원    / 평가금액 : 78832.13775 / 예수금 : 1106420.7229999995
# 43 번째거래
# -----------  kodex_active 현재가 : 12270.0  /  kodex_x2 현재가 : 38560   /  spread : 0.003503723343511362
# [sell_INFO]    kodex_active  매도금액 :  12268.1595 /  kodex_x2 매수금액 : 38565.78400000001 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1185252.6 원    / 평가금액 : 105129.502 / 예수금 : 1080123.0984999996
# 44 번째거래
# -----------  kodex_active 현재가 : 12270.0  /  kodex_x2 현재가 : 38545   /  spread : 0.003892803174630737
# [sell_INFO]    kodex_active  매도금액 :  12268.1595 /  kodex_x2 매수금액 : 38550.78175 kodex_active :  -5 주  /  kodex_x2 :  5 주
# [sell] 잔고:  1185177.36 원    / 평가금액 : 131336.88874999998 / 예수금 : 1053840.4762499996
# 45 번째거래
# -----------  kodex_active 현재가 : 12250.0  /  kodex_x2 현재가 : 38550   /  spread : 0.0021317713444336025
# [sell_INFO]    kodex_active  매도금액 :  12248.1625 /  kodex_x2 매수금액 : 38555.7825 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1185287.14 원    / 평가금액 : 157754.27999999997 / 예수금 : 1027532.8562499996
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  24426.3355 /  kodex_x2 매수금액 : 76721.5065 kodex_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1499969.66 원    / 평가금액 : 52264.829 / 예수금 : 1447704.829
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  24416.337 /  kodex_x2 매수금액 : 76601.4885 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1499829.37 원    / 평가금액 : 104309.69700000001 / 예수금 : 1395519.6775
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  24446.3325 /  kodex_x2 매수금액 : 76701.5035 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1499938.99 원    / 평가금액 : 156674.487 / 예수금 : 1343264.5065
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  24466.3295 /  kodex_x2 매수금액 : 76811.52 kodex_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1500178.55 원    / 평가금액 : 209259.23799999995 / 예수금 : 1290919.3159999999
# 5 번째거래
# -----------  kodex_active 현재가 : 12275.0  /  kodex_x2 현재가 : 38600   /  spread : 0.0028743315728351135
# [sell_INFO]    kodex_active  매도금액 :  24546.3175 /  kodex_x2 매수금액 : 77211.58 kodex_active :  -10 주  /  kodex_x2 :  10 주
# [sell] 잔고:  1501427.74 원    / 평가금액 : 263173.6875 / 예수금 : 1238254.0535
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  24576.313000000002 /  kodex_x2 매수금액 : 77211.58 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1501247.18 원    / 평가금액 : 315628.39800000004 / 예수금 : 1185618.7865
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  24576.313000000002 /  kodex_x2 매수금액 : 77261.58750000001 kodex_active :  -14 주  /  kodex_x2 :  14 주
# [sell] 잔고:  1501516.59 원    / 평가금액 : 368583.07849999995 / 예수금 : 1132933.5119999999
# 8 번째거래
# -----------  kodex_active 현재가 : 12260.0  /  kodex_x2 현재가 : 38580   /  spread : 0.00216985739351842
# [sell_INFO]    kodex_active  매도금액 :  24516.322 /  kodex_x2 매수금액 : 77171.57400000001 kodex_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1501276.24 원    / 평가금액 : 420997.98400000005 / 예수금 : 1080278.2599999998
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77261.58750000001 tiger_active :  -2 주  /  kodex_x2 :  2 주
# [sell] 잔고:  1620916.6 원    / 평가금액 : 593313.6115 / 예수금 : 1027602.9839999997
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77261.58750000001 kodex_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1448730.22 원    / 평가금액 : 473802.516 / 예수금 : 974927.7079999996
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77271.589 kodex_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  1448789.66 원    / 평가금액 : 526547.225 / 예수금 : 922242.4304999997
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  24576.313000000002 /  kodex_x2 매수금액 : 77291.592 kodex_active :  -22 주  /  kodex_x2 :  22 주
# [sell] 잔고:  1449059.08 원    / 평가금액 : 579531.931 / 예수금 : 869527.1514999997
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  24586.3115 /  kodex_x2 매수금액 : 77261.58750000001 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1448588.56 원    / 평가금액 : 631736.6880000001 / 예수금 : 816851.8754999996
# 14 번째거래
# -----------  kodex_active 현재가 : 12255.0  /  kodex_x2 현재가 : 38540   /  spread : 0.0027992883568913763
# [sell_INFO]    kodex_active  매도금액 :  24506.3235 /  kodex_x2 매수금액 : 77091.562 kodex_active :  -26 주  /  kodex_x2 :  26 주
# [sell] 잔고:  1447478.54 원    / 평가금액 : 683211.8995 / 예수금 : 764266.6369999996
# 15 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  24556.316 /  kodex_x2 매수금액 : 77251.58600000001 kodex_active :  -28 주  /  kodex_x2 :  28 주
# [sell] 잔고:  1448877.59 원    / 평가금액 : 737306.22 / 예수금 : 711571.3669999996
# 16 번째거래
# -----------  kodex_active 현재가 : 12280.0  /  kodex_x2 현재가 : 38620   /  spread : 0.002763580081663917
# [sell_INFO]    kodex_active  매도금액 :  24556.316 /  kodex_x2 매수금액 : 77251.58600000001 kodex_active :  -30 주  /  kodex_x2 :  30 주
# [sell] 잔고:  1448847.05 원    / 평가금액 : 789970.95 / 예수금 : 658876.0969999996
# 17 번째거래
# -----------  kodex_active 현재가 : 12240.0  /  kodex_x2 현재가 : 38525   /  spread : 0.001963830241036465
# [sell_INFO]    kodex_active  매도금액 :  24476.328 /  kodex_x2 매수금액 : 77061.55750000001 kodex_active :  -32 주  /  kodex_x2 :  32 주
# [sell] 잔고:  1447167.2 원    / 평가금액 : 840876.328 / 예수금 : 606290.8674999996
# 18 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38440   /  spread : 0.00212805497064808
# [sell_INFO]    kodex_active  매도금액 :  24426.3355 /  kodex_x2 매수금액 : 76891.532 kodex_active :  -34 주  /  kodex_x2 :  34 주
# [sell] 잔고:  1445217.33 원    / 평가금액 : 891391.6595 / 예수금 : 553825.6709999996
# 19 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38370   /  spread : 0.0019019735973550764
# [sell_INFO]    kodex_active  매도금액 :  24376.343 /  kodex_x2 매수금액 : 76751.51100000001 kodex_active :  -36 주  /  kodex_x2 :  36 주
# [sell] 잔고:  1443657.48 원    / 평가금액 : 942206.9759999998 / 예수금 : 501450.5029999996
# 20 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76811.52 tiger_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1782380.62 원    / 평가금액 : 1333305.3080000002 / 예수금 : 449075.31699999963
# 21 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38465   /  spread : 0.003951771040069019
# [sell_INFO]    tiger_active  매도금액 :  24456.331000000002 /  kodex_x2 매수금액 : 76941.53950000001 tiger_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1707731.39 원    / 평가금액 : 1311141.2820000001 / 예수금 : 396590.1084999996
# 22 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38395   /  spread : 0.0016607232484127585
# [sell_INFO]    kodex_active  매도금액 :  24386.3415 /  kodex_x2 매수금액 : 76801.5185 kodex_active :  -38 주  /  kodex_x2 :  38 주
# [sell] 잔고:  1339486.57 원    / 평가금액 : 995311.6370000001 / 예수금 : 344174.9314999996
# 23 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76811.52 tiger_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1653006.2 원    / 평가금액 : 1361206.456 / 예수금 : 291799.7454999996
# 24 번째거래
# -----------  kodex_active 현재가 : 12195.0  /  kodex_x2 현재가 : 38385   /  spread : 0.0019212077510578213
# [sell_INFO]    kodex_active  매도금액 :  24386.3415 /  kodex_x2 매수금액 : 76781.51550000001 kodex_active :  -40 주  /  kodex_x2 :  40 주
# [sell] 잔고:  1286701.09 원    / 평가금액 : 1047296.5199999999 / 예수금 : 239404.5714999996
# 25 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38470   /  spread : 0.0038217911867632487
# [sell_INFO]    tiger_active  매도금액 :  24456.331000000002 /  kodex_x2 매수금액 : 76951.54100000001 tiger_active :  -10 주  /  kodex_x2 :  10 주
# [sell] 잔고:  1603160.2 원    / 평가금액 : 1416250.835 / 예수금 : 186909.3614999996
# 26 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38435   /  spread : 0.0030764669228764852
# [sell_INFO]    kodex_active  매도금액 :  24446.3325 /  kodex_x2 매수금액 : 76881.53050000001 kodex_active :  -42 주  /  kodex_x2 :  42 주
# [sell] 잔고:  1234975.01 원    / 평가금액 : 1100500.842 / 예수금 : 134474.1634999996
# 27 번째거래
# -----------  tiger_active 현재가 : 12235  /  kodex_x2 현재가 : 38435   /  spread : 0.005140752345425683
# [sell_INFO]    tiger_active  매도금액 :  24466.3295 /  kodex_x2 매수금액 : 76881.53050000001 tiger_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1549244.8 원    / 평가금액 : 1467185.8365 / 예수금 : 82058.96249999959
# 28 번째거래
# -----------  kodex_active 현재가 : 12190.0  /  kodex_x2 현재가 : 38375   /  spread : 0.0017716719488548582
# [sell_INFO]    kodex_active  매도금액 :  24376.343 /  kodex_x2 매수금액 : 76761.51250000001 kodex_active :  -44 주  /  kodex_x2 :  44 주
# [sell] 잔고:  1181480.06 원    / 평가금액 : 1151806.2710000002 / 예수금 : 29673.792999999576
# 29 번째거래
# -----------  tiger_active 현재가 : 12205  /  kodex_x2 현재가 : 38355   /  spread : 0.004769364685549761
# [sell_INFO]    tiger_active  매도금액 :  24406.3385 /  kodex_x2 매수금액 : 76721.5065 tiger_active :  -14 주  /  kodex_x2 :  14 주
# [sell] 잔고:  1493829.85 원    / 평가금액 : 1516471.2265 / 예수금 : -22641.37500000043
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  36639.50325 /  kodex_x2 매수금액 : 115082.25975000001 kodex_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1499954.49 원    / 평가금액 : 78397.2435 / 예수금 : 1421557.2434999999
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  36624.5055 /  kodex_x2 매수금액 : 114902.23275000001 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1499744.06 원    / 평가금액 : 156464.5455 / 예수금 : 1343279.5162499999
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  36669.49875 /  kodex_x2 매수금액 : 115052.25525000002 kodex_active :  -9 주  /  kodex_x2 :  9 주
# [sell] 잔고:  1499908.49 원    / 평가금액 : 235011.73049999998 / 예수금 : 1264896.7597499997
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# ...
# [sell_INFO]    tiger_active  매도금액 :  24536.319 /  kodex_x2 매수금액 : 77251.58600000001 tiger_active :  -10 주  /  kodex_x2 :  10 주
# [sell] 잔고:  1361187.09 원    / 평가금액 : 649565.735 / 예수금 : 711621.3594999998
# 16 번째거래
# -----------  tiger_active 현재가 : 12275  /  kodex_x2 현재가 : 38620   /  spread : 0.00360295493210187
# [sell_INFO]    tiger_active  매도금액 :  24546.3175 /  kodex_x2 매수금액 : 77251.58600000001 tiger_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1283878.14 원    / 평가금액 : 624962.045 / 예수금 : 658916.0909999998
# 17 번째거래
# -----------  tiger_active 현재가 : 12265  /  kodex_x2 현재가 : 38525   /  spread : 0.005250854756159173
# [sell_INFO]    tiger_active  매도금액 :  24526.3205 /  kodex_x2 매수금액 : 77061.55750000001 tiger_active :  -14 주  /  kodex_x2 :  14 주
# [sell] 잔고:  1205029.52 원    / 평가금액 : 598648.6685 / 예수금 : 606380.8539999998
# 18 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38440   /  spread : 0.004601923848875301
# [sell_INFO]    tiger_active  매도금액 :  24456.331000000002 /  kodex_x2 매수금액 : 76891.532 tiger_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1126920.98 원    / 평가금액 : 572975.328 / 예수금 : 553945.6529999998
# 19 번째거래
# -----------  tiger_active 현재가 : 12225  /  kodex_x2 현재가 : 38370   /  spread : 0.00601568935396069
# [sell_INFO]    tiger_active  매도금액 :  24446.3325 /  kodex_x2 매수금액 : 76751.51100000001 tiger_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1048842.36 원    / 평가금액 : 547201.8825000001 / 예수금 : 501640.4744999998
# 20 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76811.52 tiger_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  972713.43 원    / 평가금액 : 523448.14 / 예수금 : 449265.2884999998
# 21 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38465   /  spread : 0.003951771040069019
# [sell_INFO]    tiger_active  매도금액 :  24456.331000000002 /  kodex_x2 매수금액 : 76941.53950000001 tiger_active :  -22 주  /  kodex_x2 :  22 주
# [sell] 잔고:  896864.33 원    / 평가금액 : 500084.246 / 예수금 : 396780.0799999998
# 22 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38395   /  spread : 0.004955269212828616
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76801.5185 tiger_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  818875.72 원    / 평가금액 : 474460.82300000003 / 예수금 : 344414.89549999975
# 23 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38400   /  spread : 0.004825052401654309
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76811.52 tiger_active :  -26 주  /  kodex_x2 :  26 주
# [sell] 잔고:  742156.85 원    / 평가금액 : 450117.142 / 예수금 : 292039.70949999976
# 24 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38385   /  spread : 0.005215753715473679
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76781.51550000001 tiger_active :  -28 주  /  kodex_x2 :  28 주
# [sell] 잔고:  665068.05 원    / 평가금액 : 425373.52099999995 / 예수금 : 239694.52799999976
# 25 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38470   /  spread : 0.0038217911867632487
# [sell_INFO]    tiger_active  매도금액 :  24456.331000000002 /  kodex_x2 매수금액 : 76951.54100000001 tiger_active :  -30 주  /  kodex_x2 :  30 주
# [sell] 잔고:  589528.87 원    / 평가금액 : 402329.55499999993 / 예수금 : 187199.31799999974
# 26 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38435   /  spread : 0.0030764669228764852
# [sell_INFO]    kodex_active  매도금액 :  24446.3325 /  kodex_x2 매수금액 : 76881.53050000001 kodex_active :  -22 주  /  kodex_x2 :  22 주
# [sell] 잔고:  711216.94 원    / 평가금액 : 576452.822 / 예수금 : 134764.11999999973
# 27 번째거래
# -----------  tiger_active 현재가 : 12235  /  kodex_x2 현재가 : 38435   /  spread : 0.005140752345425683
# [sell_INFO]    tiger_active  매도금액 :  24466.3295 /  kodex_x2 매수금액 : 76881.53050000001 tiger_active :  -32 주  /  kodex_x2 :  32 주
# [sell] 잔고:  536213.36 원    / 평가금액 : 453864.4365 / 예수금 : 82348.91899999973
# 28 번째거래
# -----------  tiger_active 현재가 : 12220  /  kodex_x2 현재가 : 38375   /  spread : 0.005476306087974071
# [sell_INFO]    tiger_active  매도금액 :  24436.334 /  kodex_x2 매수금액 : 76761.51250000001 tiger_active :  -34 주  /  kodex_x2 :  34 주
# [sell] 잔고:  458604.78 원    / 평가금액 : 428581.0405 / 예수금 : 30023.740499999723
# 29 번째거래
# -----------  tiger_active 현재가 : 12205  /  kodex_x2 현재가 : 38355   /  spread : 0.004769364685549761
# [sell_INFO]    tiger_active  매도금액 :  24406.3385 /  kodex_x2 매수금액 : 76721.5065 tiger_active :  -36 주  /  kodex_x2 :  36 주
# [sell] 잔고:  381946.09 원    / 평가금액 : 404237.5215 / 예수금 : -22291.42750000028
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  36639.50325 /  kodex_x2 매수금액 : 115082.25975000001 kodex_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1499954.49 원    / 평가금액 : 78397.2435 / 예수금 : 1421557.2434999999
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  36624.5055 /  kodex_x2 매수금액 : 114902.23275000001 kodex_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1499744.06 원    / 평가금액 : 156464.5455 / 예수금 : 1343279.5162499999
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  36669.49875 /  kodex_x2 매수금액 : 115052.25525000002 kodex_active :  -9 주  /  kodex_x2 :  9 주
# [sell] 잔고:  1499908.49 원    / 평가금액 : 235011.73049999998 / 예수금 : 1264896.7597499997
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  36699.49425 /  kodex_x2 매수금액 : 115217.28000000001 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1500267.83 원    / 평가금액 : 313888.85699999996 / 예수금 : 1186378.9739999997
# 5 번째거래
# -----------  tiger_active 현재가 : 12280  /  kodex_x2 현재가 : 38600   /  spread : 0.004528204500097395
# [sell_INFO]    tiger_active  매도금액 :  36834.474 /  kodex_x2 매수금액 : 115817.37000000001 tiger_active :  -3 주  /  kodex_x2 :  3 주
# [sell] 잔고:  1533681.07 원    / 평가금액 : 426284.994 / 예수금 : 1107396.0779999997
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  36864.4695 /  kodex_x2 매수금액 : 115817.37000000001 kodex_active :  -15 주  /  kodex_x2 :  15 주
# [sell] 잔고:  1422978.67 원    / 평가금액 : 394535.4975 / 예수금 : 1028443.1774999998
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  36864.4695 /  kodex_x2 매수금액 : 115892.38125 kodex_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1423307.8 원    / 평가금액 : 473892.5295 / 예수금 : 949415.2657499998
# 8 번째거래
# -----------  tiger_active 현재가 : 12280  /  kodex_x2 현재가 : 38580   /  spread : 0.0050464734932995775
# [sell_INFO]    tiger_active  매도금액 :  36834.474 /  kodex_x2 매수금액 : 115757.361 tiger_active :  -6 주  /  kodex_x2 :  6 주
# [sell] 잔고:  1491137.16 원    / 평가금액 : 620644.782 / 예수금 : 870492.3787499998
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115892.38125 tiger_active :  -9 주  /  kodex_x2 :  9 주
# [sell] 잔고:  1375953.58 원    / 평가금액 : 584474.11425 / 예수금 : 791479.4647499998
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115892.38125 kodex_active :  -21 주  /  kodex_x2 :  21 주
# [sell] 잔고:  1265236.15 원    / 평가금액 : 552769.602 / 예수금 : 712466.5507499998
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115907.38350000001 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1265295.3 원    / 평가금액 : 631856.6699999999 / 예수금 : 633438.6344999998
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  36864.4695 /  kodex_x2 매수금액 : 115937.388 kodex_active :  -27 주  /  kodex_x2 :  27 주
# [sell] 잔고:  1265609.45 원    / 평가금액 : 711243.7335 / 예수금 : 554365.7159999998
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  36879.46725 /  kodex_x2 매수금액 : 115892.38125 kodex_active :  -30 주  /  kodex_x2 :  30 주
# [sell] 잔고:  1265023.66 원    / 평가금액 : 789670.86 / 예수금 : 475352.8019999998
# 14 번째거래
# -----------  tiger_active 현재가 : 12265  /  kodex_x2 현재가 : 38540   /  spread : 0.004861572976118269
# [sell_INFO]    tiger_active  매도금액 :  36789.48075 /  kodex_x2 매수금액 : 115637.34300000001 tiger_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1405329.43 원    / 평가금액 : 1008824.493 / 예수금 : 396504.9397499998
# 15 번째거래
# -----------  tiger_active 현재가 : 12270  /  kodex_x2 현재가 : 38620   /  spread : 0.003195539974337719
# [sell_INFO]    tiger_active  매도금액 :  36804.4785 /  kodex_x2 매수금액 : 115877.37900000002 tiger_active :  -15 주  /  kodex_x2 :  15 주
# [sell] 잔고:  1291780.64 원    / 평가금액 : 974348.6024999999 / 예수금 : 317432.0392499998
# 16 번째거래
# -----------  tiger_active 현재가 : 12275  /  kodex_x2 현재가 : 38620   /  spread : 0.00360295493210187
# [sell_INFO]    tiger_active  매도금액 :  36819.47625 /  kodex_x2 매수금액 : 115877.37900000002 tiger_active :  -18 주  /  kodex_x2 :  18 주
# [sell] 잔고:  1175817.2 원    / 평가금액 : 937443.0674999999 / 예수금 : 238374.1364999998
# 17 번째거래
# -----------  tiger_active 현재가 : 12265  /  kodex_x2 현재가 : 38525   /  spread : 0.005250854756159173
# [sell_INFO]    tiger_active  매도금액 :  36789.48075 /  kodex_x2 매수금액 : 115592.33625000001 tiger_active :  -21 주  /  kodex_x2 :  21 주
# [sell] 잔고:  1057544.28 원    / 평가금액 : 897973.00275 / 예수금 : 159571.28099999978
# 18 번째거래
# -----------  tiger_active 현재가 : 12230  /  kodex_x2 현재가 : 38440   /  spread : 0.004601923848875301
# [sell_INFO]    tiger_active  매도금액 :  36684.4965 /  kodex_x2 매수금액 : 115337.29800000001 tiger_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  940381.47 원    / 평가금액 : 859462.992 / 예수금 : 80918.47949999978
# 19 번째거래
# -----------  tiger_active 현재가 : 12225  /  kodex_x2 현재가 : 38370   /  spread : 0.00601568935396069
# [sell_INFO]    tiger_active  매도금액 :  36669.49875 /  kodex_x2 매수금액 : 115127.26650000001 tiger_active :  -27 주  /  kodex_x2 :  27 주
# [sell] 잔고:  823263.54 원    / 평가금액 : 820802.82375 / 예수금 : 2460.7117499997694
# 20 번째거래
# 금액부족
# 21 번째거래
# 금액부족
# 22 번째거래
# 금액부족
# 23 번째거래
# 금액부족
# 24 번째거래
# 금액부족
# 25 번째거래
# 금액부족
# 26 번째거래
# 금액부족
# 27 번째거래
# 금액부족
# 28 번째거래
# 금액부족
# 29 번째거래
# 금액부족
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1 번째거래
# -----------  kodex_active 현재가 : 12215.0  /  kodex_x2 현재가 : 38355   /  spread : 0.004341741661480082
# [sell_INFO]    kodex_active  매도금액 :  48852.671 /  kodex_x2 매수금액 : 153443.013 kodex_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1499939.32 원    / 평가금액 : 104529.658 / 예수금 : 1395409.658
# 2 번째거래
# -----------  kodex_active 현재가 : 12210.0  /  kodex_x2 현재가 : 38295   /  spread : 0.005497883124092351
# [sell_INFO]    kodex_active  매도금액 :  48832.674 /  kodex_x2 매수금액 : 153202.977 kodex_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1499658.75 원    / 평가금액 : 208619.39400000003 / 예수금 : 1291039.355
# 3 번째거래
# -----------  kodex_active 현재가 : 12225.0  /  kodex_x2 현재가 : 38345   /  spread : 0.005420828507149127
# [sell_INFO]    kodex_active  매도금액 :  48892.665 /  kodex_x2 매수금액 : 153403.007 kodex_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1499877.99 원    / 평가금액 : 313348.974 / 예수금 : 1186529.013
# 4 번째거래
# -----------  kodex_active 현재가 : 12235.0  /  kodex_x2 현재가 : 38400   /  spread : 0.004805171663989962
# [sell_INFO]    kodex_active  매도금액 :  48932.659 /  kodex_x2 매수금액 : 153623.04 kodex_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1500357.11 원    / 평가금액 : 418518.4759999999 / 예수금 : 1081838.632
# 5 번째거래
# -----------  tiger_active 현재가 : 12280  /  kodex_x2 현재가 : 38600   /  spread : 0.004528204500097395
# [sell_INFO]    tiger_active  매도금액 :  49112.632 /  kodex_x2 매수금액 : 154423.16 tiger_active :  -4 주  /  kodex_x2 :  4 주
# [sell] 잔고:  1544908.1 원    / 평가금액 : 568379.992 / 예수금 : 976528.1039999999
# 6 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38600   /  spread : 0.004095581470194228
# [sell_INFO]    kodex_active  매도금액 :  49152.626000000004 /  kodex_x2 매수금액 : 154423.16 kodex_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  1397304.9 원    / 평가금액 : 526047.3300000001 / 예수금 : 871257.57
# 7 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003448122723069838
# [sell_INFO]    kodex_active  매도금액 :  49152.626000000004 /  kodex_x2 매수금액 : 154523.17500000002 kodex_active :  -24 주  /  kodex_x2 :  24 주
# [sell] 잔고:  1397743.73 원    / 평가금액 : 631856.706 / 예수금 : 765887.021
# 8 번째거래
# -----------  tiger_active 현재가 : 12280  /  kodex_x2 현재가 : 38580   /  spread : 0.0050464734932995775
# [sell_INFO]    tiger_active  매도금액 :  49112.632 /  kodex_x2 매수금액 : 154343.14800000002 tiger_active :  -8 주  /  kodex_x2 :  8 주
# [sell] 잔고:  1488182.88 원    / 평가금액 : 827526.3759999999 / 예수금 : 660656.5049999999
# 9 번째거래
# -----------  tiger_active 현재가 : 12295  /  kodex_x2 현재가 : 38625   /  spread : 0.005101498702132327
# [sell_INFO]    tiger_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154523.17500000002 tiger_active :  -12 주  /  kodex_x2 :  12 주
# [sell] 잔고:  1334604.77 원    / 평가금액 : 779298.819 / 예수금 : 555305.9529999999
# 10 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154523.17500000002 kodex_active :  -28 주  /  kodex_x2 :  28 주
# [sell] 잔고:  1186981.54 원    / 평가금액 : 737026.1359999999 / 예수금 : 449955.40099999984
# 11 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38630   /  spread : 0.003725433353001989
# [sell_INFO]    kodex_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154543.178 kodex_active :  -32 주  /  kodex_x2 :  32 주
# [sell] 잔고:  1187060.41 원    / 평가금액 : 842475.56 / 예수금 : 344584.8459999998
# 12 번째거래
# -----------  kodex_active 현재가 : 12290.0  /  kodex_x2 현재가 : 38640   /  spread : 0.0030598485966621056
# [sell_INFO]    kodex_active  매도금액 :  49152.626000000004 /  kodex_x2 매수금액 : 154583.184 kodex_active :  -36 주  /  kodex_x2 :  36 주
# [sell] 잔고:  1187479.27 원    / 평가금액 : 948324.978 / 예수금 : 239154.28799999977
# 13 번째거래
# -----------  kodex_active 현재가 : 12295.0  /  kodex_x2 현재가 : 38625   /  spread : 0.003854874813282401
# [sell_INFO]    kodex_active  매도금액 :  49172.623 /  kodex_x2 매수금액 : 154523.17500000002 kodex_active :  -40 주  /  kodex_x2 :  40 주
# [sell] 잔고:  1186698.22 원    / 평가금액 : 1052894.48 / 예수금 : 133803.73599999974
# 14 번째거래
# -----------  tiger_active 현재가 : 12265  /  kodex_x2 현재가 : 38540   /  spread : 0.004861572976118269
# [sell_INFO]    tiger_active  매도금액 :  49052.641 /  kodex_x2 매수금액 : 154183.124 tiger_active :  -16 주  /  kodex_x2 :  16 주
# [sell] 잔고:  1373772.58 원    / 평가금액 : 1345099.324 / 예수금 : 28673.252999999735
# 15 번째거래
# -----------  tiger_active 현재가 : 12270  /  kodex_x2 현재가 : 38620   /  spread : 0.003195539974337719
# [sell_INFO]    tiger_active  매도금액 :  49072.638 /  kodex_x2 매수금액 : 154503.17200000002 tiger_active :  -20 주  /  kodex_x2 :  20 주
# [sell] 잔고:  1222374.19 원    / 평가금액 : 1299131.47 / 예수금 : -76757.28100000028
# 16 번째거래
# 금액부족
# 17 번째거래
# 금액부족
# 18 번째거래
# 금액부족
# 19 번째거래
# 금액부족
# 20 번째거래
# 금액부족
# 21 번째거래
# 금액부족
# 22 번째거래
# 금액부족
# 23 번째거래
# 금액부족
# 24 번째거래
# 금액부족
# 25 번째거래
# 금액부족
# 26 번째거래
# 금액부족
# 27 번째거래
# 금액부족
# 28 번째거래
# 금액부족
# 29 번째거래
# 금액부족
# 30 번째거래
# 금액부족
# 31 번째거래
# 금액부족
# 32 번째거래
# 금액부족
# 33 번째거래
# 금액부족
# 34 번째거래
# 금액부족
# 35 번째거래
# 금액부족
# 36 번째거래
# 금액부족
# 37 번째거래
# 금액부족
# 38 번째거래
# 금액부족
# 39 번째거래
# 금액부족
# 40 번째거래
# 금액부족
# 41 번째거래
# 금액부족
# 42 번째거래
# 금액부족
# 43 번째거래
# 금액부족
# 44 번째거래
# 금액부족
# 45 번째거래
# 금액부족
# 1503386.7204999998 [0.003, 2]

# %%
backtest_df = pd.DataFrame(backtest).transpose() ; backtest_df.columns = ['profit','threshold & lev']
thres = [ backtest_df['threshold & lev'].values[i][0] for i in range(len(backtest_df)) ]
lev = [ backtest_df['threshold & lev'].values[i][1] for i in range(len(backtest_df)) ]
backtest_df
# pd.DataFrame(profits).transpose()
# Out:
#                  profit threshold & lev
# 20201223 3009320.378000      [0.003, 4]
# 20201224 3005303.779000      [0.003, 4]
# 20201228 4747587.779000      [0.003, 4]

# %% [markdown]
# # 백테스트

# %%
test.trade('test',1000000, 5, 20)

# %% [markdown]
# ## 윈도우 사이즈 그리드 서치

# %%
# train
# length_scores = {}
# for i in range(1,20):
#     for j in range(5,60):
#         length_scores[test.trade('train',1000000, i, j)] = (i,j)
# best_length = max(length_scores.keys())
# print ('Best window length:', length_scores[best_length])
# print (best_length, 'day window:', length_scores[best_length])

# Test
length_scores2 = {}
for i in range(1,20):
    for j in range(5,60):
        length_scores2[test.trade('test',1000000, i, j)] = (i,j)
best_length2 = max(length_scores2.keys())
print (best_length2, 'day window:', length_scores2[best_length2])

# %%
plt.figure(figsize=(15,7))
plt.plot(length_scores)
plt.plot(length_scores2)
plt.xlabel('Window length')
plt.ylabel('Score')
plt.legend(['Training', 'Test'])
plt.show()

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------------------------------
